# %%
##LINK OF DATASET:- kaggle datasets download -d teejmahal20/airline-passenger-satisfaction

import pandas as pd

df = pd.read_csv('airline.csv')
df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.shape
print(" ROWS: ",df.shape[0],"\n","Columns: ",df.shape[1])
# Out:
#  ROWS:  25976
#  Columns:  25

# %%
import matplotlib.pyplot as plt

satisfaction_counts = df['satisfaction'].value_counts()
labels = satisfaction_counts.index
sizes = satisfaction_counts.values
colors = ['lightcoral', 'lightskyblue']
  
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%',startangle=140)

plt.title('Airline Passenger Satisfaction Distribution')
plt.axis('equal') 

plt.show()

# %%
df.isnull()
# Out:
#        Unnamed: 0     id  Gender  Customer Type    Age  Type of Travel  Class  \
# 0           False  False   False          False  False           False  False
# 1           False  False   False          False  False           False  False
# 2           False  False   False          False  False           False  False
# 3           False  False   False          False  False           False  False
# 4           False  False   False          False  False           False  False
# ...           ...    ...     ...            ...    ...             ...    ...
# 25971       False  False   False          False  False           False  False
# 25972       False  False   False          False  False           False  False
# 25973       False  False   False          False  False           False  False
# 25974       False  False   False          False  False           False  False
# 25975       False  False   False          False  False           False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
df = df.fillna(df['Arrival Delay in Minutes'].mean)
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0             id  Gender   Customer Type           Age  \
# count   25976.000000   25976.000000   25976           25976  25976.000000
# unique           NaN            NaN       2               2           NaN
# top              NaN            NaN  Female  Loyal Customer           NaN
# freq             NaN            NaN   13172           21177           NaN
# mean    12987.500000   65005.657992     NaN             NaN     39.620958
# std      7498.769632   37611.526647     NaN             NaN     15.135685
# min         0.000000      17.000000     NaN             NaN      7.000000
# 25%      6493.750000   32170.500000     NaN             NaN     27.000000
# 50%     12987.500000   65319.500000     NaN             NaN     40.000000
# 75%     19481.250000   97584.250000     NaN             NaN     51.000000
# max     25975.000000  129877.000000     NaN             NaN     85.000000
#
#          Type of Travel     Class  Flight Distance  Inflight wifi service  \
# ...

# %%
#Splitting the entire data into train and test data....

from sklearn.model_selection import train_test_split

df['satisfaction'].value_counts()
y=df.replace({'satisfaction':{'neutral or dissatisfied':0,'satisfied':1}})
y=y['satisfaction']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 25971    0
# 25972    1
# 25973    0
# 25974    1
# 25975    0
# Name: satisfaction, Length: 25976, dtype: int64

# %%
print(df['Customer Type'].value_counts())
print(df['Type of Travel'].value_counts())
df = df.replace({'Customer Type':{'Loyal Customer':1,'disloyal Customer':0}})
df = df.replace({'Type of Travel':{'Business travel':1,'Personal Travel':0}})
df.head()
# Out:
# Customer Type
# Loyal Customer       21177
# disloyal Customer     4799
# Name: count, dtype: int64
# Type of Travel
# Business travel    18038
# Personal Travel     7938
# Name: count, dtype: int64
#    Unnamed: 0     id  Gender  Customer Type  Age  Type of Travel     Class  \
# 0           0  19556  Female              1   52               1       Eco
# 1           1  90035  Female              1   36               1  Business
# 2           2  12360    Male              0   20               1       Eco
# 3           3  77959    Male              1   44               1  Business
# 4           4  36875  Female              1   49               1       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              160                      5                                  4
# 1             2863                      1                                  1
# 2              192                      2                                  0
# ...

# %%
columns = ['Customer Type', 'Age', 'Type of Travel', 'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes']
X = df[columns]
X
# Out:
#        Customer Type  Age  Type of Travel  Flight Distance  \
# 0                  1   52               1              160
# 1                  1   36               1             2863
# 2                  0   20               1              192
# 3                  1   44               1             3377
# 4                  1   49               1             1182
# ...              ...  ...             ...              ...
# 25971              0   34               1              526
# 25972              1   23               1              646
# 25973              1   17               0              828
# 25974              1   14               1             1127
# 25975              1   42               0              264
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# 0                          5                                  4
# 1                          1                                  1
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=23)

# %%
X_train
# Out:
#        Customer Type  Age  Type of Travel  Flight Distance  \
# 4789               1   20               0             1028
# 11317              1   45               1             1121
# 8074               1   35               0              603
# 20000              1   39               1             3111
# 17256              1   59               1             1171
# ...              ...  ...             ...              ...
# 6175               0   43               1              588
# 9704               0   24               1              946
# 11190              1   45               1             1902
# 9256               1   12               0             1399
# 8787               1   46               0              214
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# 4789                       2                                  4
# 11317                      2                                  3
# ...

# %%
X_test
# Out:
#        Customer Type  Age  Type of Travel  Flight Distance  \
# 13260              1   50               1              262
# 10580              1   45               0              438
# 10735              1   61               0              364
# 20154              1   45               1             1608
# 15000              1    9               0              689
# ...              ...  ...             ...              ...
# 19135              1   44               0              925
# 5185               1   36               1             1625
# 22158              1    8               0              590
# 11109              1   54               0              621
# 17282              1   21               1             1594
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# 13260                      4                                  1
# 10580                      3                                  5
# ...

# %%
y_train
# Out:
# 4789     0
# 11317    0
# 8074     0
# 20000    1
# 17256    0
#         ..
# 6175     0
# 9704     0
# 11190    1
# 9256     0
# 8787     0
# Name: satisfaction, Length: 20780, dtype: int64

# %%
y_test
# Out:
# 13260    1
# 10580    0
# 10735    0
# 20154    0
# 15000    0
#         ..
# 19135    0
# 5185     0
# 22158    0
# 11109    0
# 17282    1
# Name: satisfaction, Length: 5196, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model = DecisionTreeClassifier()
model.fit(X_train,y_train)
prediction = model.predict(X_test)
print(prediction)
accuracy = accuracy_score(y_test,prediction)
accuracy
# Out:
# [1 0 0 ... 0 0 0]
# 0.928598922247883

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plot_tree(model, filled=True, feature_names=columns, class_names=['Neutral or Dissatisfied', 'Satisfied'])
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

precision = precision_score(y_test, prediction)
recall = recall_score(y_test, prediction)
f1 = f1_score(y_test, prediction)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
# Out:
# Accuracy: 0.93
# Precision: 0.91
# Recall: 0.92
# F1-score: 0.92

# %%
from sklearn import metrics
cn = metrics.confusion_matrix(y_test,prediction)
cn
# Out:
# array([[2760,  198],
#        [ 173, 2065]])
